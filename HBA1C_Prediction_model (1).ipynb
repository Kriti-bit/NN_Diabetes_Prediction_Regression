# %%
# import pandas as pd
# df_temp=pd.read_csv('WiDS.csv')
# df_temp.head()

# %%
# df = df_temp[['age', 'bmi','gender','h1_glucose_max','h1_glucose_min', 'h1_hemaglobin_max', 'h1_hemaglobin_min' ]]
# df.head(20)

# %%
# df.isna().sum()

# %%
# df = df.dropna()

# %%
# df.to_csv('cleaned_data.csv')

# %%
import pandas as pd
df=pd.read_csv('cleaned_data.csv',nrows=100)
df.head()
# Out:
#    Unnamed: 0   age        bmi gender  h1_glucose_max  h1_glucose_min  \
# 0           1  77.0  27.421875      F           145.0           143.0
# 1           6  59.0  57.451002      F           197.0           194.0
# 2           9  50.0  25.707702      M           134.0           134.0
# 3          16  30.0  23.383178      M            98.0            98.0
# 4          19  39.0  37.010278      M           121.0           121.0
#
#    h1_hemaglobin_max  h1_hemaglobin_min
# 0               11.3               11.3
# 1               10.7               10.7
# 2               12.8               12.8
# 3               12.4               12.4
# 4               12.4               12.4

# %%
df.head(10)
# Out:
#    Unnamed: 0   age        bmi gender  h1_glucose_max  h1_glucose_min  \
# 0           1  77.0  27.421875      F           145.0           143.0
# 1           6  59.0  57.451002      F           197.0           194.0
# 2           9  50.0  25.707702      M           134.0           134.0
# 3          16  30.0  23.383178      M            98.0            98.0
# 4          19  39.0  37.010278      M           121.0           121.0
# 5          23  87.0  21.963763      M           144.0           137.0
# 6          48  55.0  32.205360      M            95.0            90.0
# 7          65  41.0  37.166569      M           194.0           194.0
# 8          66  70.0  25.984659      M           145.0           142.0
# 9          73  74.0  25.311715      M           161.0           158.0
#
#    h1_hemaglobin_max  h1_hemaglobin_min
# 0               11.3               11.3
# 1               10.7               10.7
# 2               12.8               12.8
# 3               12.4               12.4
# 4               12.4               12.4
# 5                9.7                9.7
# 6                9.6                9.6
# 7               13.3               13.3
# 8               12.6               12.6
# 9                7.0                7.0

# %%
df.shape
# Out:
# (100, 8)

# %%
# for i in range(len(df)):
#     mean = (df['h1_glucose_max']+df['h1_glucose_min'])/2
#     df['glucose'] = mean
df['glucose'] = (df['h1_glucose_max'] + df['h1_glucose_min']) / 2
df['h1_hemaglobin'] = (df['h1_hemaglobin_max'] + df['h1_hemaglobin_min']) / 2

# %%
df.shape
# Out:
# (100, 10)

# %%
df.head()
# Out:
#    Unnamed: 0   age        bmi gender  h1_glucose_max  h1_glucose_min  \
# 0           1  77.0  27.421875      F           145.0           143.0
# 1           6  59.0  57.451002      F           197.0           194.0
# 2           9  50.0  25.707702      M           134.0           134.0
# 3          16  30.0  23.383178      M            98.0            98.0
# 4          19  39.0  37.010278      M           121.0           121.0
#
#    h1_hemaglobin_max  h1_hemaglobin_min  glucose  h1_hemaglobin
# 0               11.3               11.3    144.0           11.3
# 1               10.7               10.7    195.5           10.7
# 2               12.8               12.8    134.0           12.8
# 3               12.4               12.4     98.0           12.4
# 4               12.4               12.4    121.0           12.4

# %%
df = df.drop('h1_glucose_max', axis = 1)
df = df.drop('h1_glucose_min', axis = 1)
df = df.drop('h1_hemaglobin_max', axis = 1)
df = df.drop('h1_hemaglobin_min', axis = 1)
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.head(10)
# Out:
#     age        bmi gender  glucose  h1_hemaglobin
# 0  77.0  27.421875      F    144.0           11.3
# 1  59.0  57.451002      F    195.5           10.7
# 2  50.0  25.707702      M    134.0           12.8
# 3  30.0  23.383178      M     98.0           12.4
# 4  39.0  37.010278      M    121.0           12.4
# 5  87.0  21.963763      M    140.5            9.7
# 6  55.0  32.205360      M     92.5            9.6
# 7  41.0  37.166569      M    194.0           13.3
# 8  70.0  25.984659      M    143.5           12.6
# 9  74.0  25.311715      M    159.5            7.0

# %%
df.gender[df.gender == 'M'] = 0
df.gender[df.gender == 'F'] = 1
# Out:
# /tmp/ipykernel_13755/3191003444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.gender[df.gender == 'M'] = 0
# /tmp/ipykernel_13755/3191003444.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.gender[df.gender == 'F'] = 1

# %%
df.head(10)
# Out:
#     age        bmi gender  glucose  h1_hemaglobin
# 0  77.0  27.421875      1    144.0           11.3
# 1  59.0  57.451002      1    195.5           10.7
# 2  50.0  25.707702      0    134.0           12.8
# 3  30.0  23.383178      0     98.0           12.4
# 4  39.0  37.010278      0    121.0           12.4
# 5  87.0  21.963763      0    140.5            9.7
# 6  55.0  32.205360      0     92.5            9.6
# 7  41.0  37.166569      0    194.0           13.3
# 8  70.0  25.984659      0    143.5           12.6
# 9  74.0  25.311715      0    159.5            7.0

# %%
X=df.drop('h1_hemaglobin',axis=1).values### independent features
y=df['h1_hemaglobin'].values###dependent features

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
#### Libraries From Pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
##### Creating Tensors
X_train=torch.tensor(X_train)
X_test=torch.tensor(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 ##### Creating Tensors
# ----> 2 X_train=torch.tensor(X_train)
#       3 X_test=torch.tensor(X_test)
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint8, and bool.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            100 non-null    float64
#  1   bmi            100 non-null    float64
#  2   gender         100 non-null    object
#  3   glucose        100 non-null    float64
#  4   h1_hemaglobin  100 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.0+ KB

# %%
df['gender'] = df['gender'].astype('float64')

# %%
X=df.drop('h1_hemaglobin',axis=1).values### independent features
y=df['h1_hemaglobin'].values###dependent features

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
##### Creating Tensors
X_train=torch.tensor(X_train)
X_test=torch.tensor(X_test)

# %%
y_train=torch.FloatTensor(y_train)
y_test=torch.FloatTensor(y_test)

# %%
df.shape
# Out:
# (100, 5)

# %%
X_train
# Out:
# tensor([[ 24.0000,  23.0874,   0.0000,  74.0000],
#         [ 62.0000,  37.1099,   1.0000, 113.0000],
#         [ 30.0000,  23.3832,   0.0000,  98.0000],
#         [ 57.0000,  25.3793,   0.0000, 204.0000],
#         [ 36.0000,  22.4393,   0.0000, 359.0000],
#         [ 42.0000,  34.9452,   0.0000, 682.5225],
#         [ 55.0000,  32.2054,   0.0000,  92.5000],
#         [ 52.0000,  28.0299,   1.0000, 132.0000],
#         [ 35.0000,  33.5827,   0.0000, 123.0000],
#         [ 62.0000,  27.3470,   1.0000, 128.0000],
#         [ 62.0000,  26.9141,   1.0000, 104.0000],
#         [ 68.0000,  28.3399,   0.0000, 149.5000],
#         [ 53.0000,  45.8214,   1.0000, 151.0000],
#         [ 66.0000,  34.9989,   0.0000, 162.0000],
#         [ 65.0000,  28.8490,   0.0000, 148.0000],
#         [ 63.0000,  16.7337,   0.0000, 187.0000],
#         [ 76.0000,  26.1359,   0.0000, 142.0000],
#         [ 75.0000,  24.8499,   1.0000, 130.0000],
#         [ 54.0000,  18.1040,   0.0000, 156.0000],
#         [ 74.0000,  25.3117,   0.0000, 159.5000],
#         [ 68.0000,  20.8818,   1.0000, 200.0000],
#         [ 82.0000,  28.4320,   0.0000, 107.5000],
#         [ 79.0000,  22.9336,   0.0000, 177.0000],
#         [ 81.0000,  27.9628,   0.0000, 167.0000],
#         [ 52.0000,  22.3157,   1.0000, 171.0000]], dtype=torch.float64)

# %%
class ANN_Model(nn.Module):
    def __init__(self,input_features=4,hidden1=25,hidden2=25,out_features=1):
        super().__init__()
        self.f_connected1=nn.Linear(input_features,hidden1)
        self.f_connected2=nn.Linear(hidden1,hidden2)
        self.out=nn.Linear(hidden2,out_features)
    def forward(self,x):
        x=F.relu(self.f_connected1(x))
        x=F.relu(self.f_connected2(x))
        x=self.out(x)
        return x

# %%
torch.manual_seed(20)
model = ANN_Model()

# %%
### Backward Propagation:- Define the loss function and the optimizer
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01) # lr refers to the learning rate

# %%
#   # Run the training loop
#   for epoch in range(0, 10): # 10 epochs at maximum
    
#     # Print epoch
#     print(f'Starting epoch {epoch+1}')
    
#     # Set current loss value
#     current_loss = 0.0
    
#     # Iterate over the DataLoader for training data
#     for i, data in enumerate(X_test):
      
#       # Get and prepare inputs
#       inputs, targets = data
#       inputs, targets = inputs.float(), targets.float()
#       targets = targets.reshape((targets.shape[0], 1))
      
#       # Zero the gradients
#       optimizer.zero_grad()
      
#       # Perform forward pass
#       outputs = mlp(inputs)
      
#       # Compute loss
#       loss = loss_function(outputs, targets)
      
#       # Perform backward pass
#       loss.backward()
      
#       # Perform optimization
#       optimizer.step()
      
#       # Print statistics
#       current_loss += loss.item()
#       if i % 10 == 0:
#           print('Loss after mini-batch %5d: %.3f' %
#                 (i + 1, current_loss / 500))
#           current_loss = 0.0

#   # Process is complete.
#   print('Training process has finished.')
    
    
epochs = 500
final_losses = []
for i in range(epochs):
    i = i + 1
    y_pred = model.forward(X_train.float())
    loss=loss_function(y_pred, y_train)
    final_losses.append(loss.item())
    if i%10==1:
        print("Epoch number: {} and the loss: {}".format(i, loss.item()))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# /home/welcom/miniconda3/lib/python3.9/site-packages/torch/nn/modules/loss.py:530: UserWarning: Using a target size (torch.Size([80])) that is different to the input size (torch.Size([80, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch number: 1 and the loss: 392.55804443359375
# Epoch number: 11 and the loss: 35.81908416748047
# Epoch number: 21 and the loss: 17.077730178833008
# Epoch number: 31 and the loss: 11.357830047607422
# Epoch number: 41 and the loss: 10.67642593383789
# Epoch number: 51 and the loss: 9.716781616210938
# Epoch number: 61 and the loss: 9.327447891235352
# Epoch number: 71 and the loss: 9.045219421386719
# Epoch number: 81 and the loss: 8.901764869689941
# Epoch number: 91 and the loss: 8.813504219055176
# Epoch number: 101 and the loss: 8.755531311035156
# Epoch number: 111 and the loss: 8.715402603149414
# Epoch number: 121 and the loss: 8.680756568908691
# Epoch number: 131 and the loss: 8.647743225097656
# Epoch number: 141 and the loss: 8.616263389587402
# Epoch number: 151 and the loss: 8.58486270904541
# Epoch number: 161 and the loss: 8.552996635437012
# Epoch number: 171 and the loss: 8.520787239074707
# Epoch number: 181 and the loss: 8.487687110900879
# Epoch number: 191 and the loss: 8.45417308807373
# Epoch number: 201 and the loss: 8.420106887817383
# Epoch number: 211 and the loss: 8.384858131408691
# Epoch number: 221 and the loss: 8.34903335571289
# Epoch number: 231 and the loss: 8.311476707458496
# Epoch number: 241 and the loss: 8.273776054382324
# Epoch number: 251 and the loss: 8.235204696655273
# Epoch number: 261 and the loss: 8.195537567138672
# Epoch number: 271 and the loss: 8.15441608428955
# Epoch number: 281 and the loss: 8.111614227294922
# Epoch number: 291 and the loss: 8.067732810974121
# Epoch number: 301 and the loss: 8.021857261657715
# Epoch number: 311 and the loss: 7.97353982925415
# Epoch number: 321 and the loss: 7.92340087890625
# Epoch number: 331 and the loss: 7.871047496795654
# Epoch number: 341 and the loss: 7.815704345703125
# Epoch number: 351 and the loss: 7.757627010345459
# Epoch number: 361 and the loss: 7.696292877197266
# Epoch number: 371 and the loss: 7.6315484046936035
# Epoch number: 381 and the loss: 7.562845230102539
# Epoch number: 391 and the loss: 7.489780902862549
# Epoch number: 401 and the loss: 7.412267684936523
# Epoch number: 411 and the loss: 7.328399658203125
# Epoch number: 421 and the loss: 7.237750053405762
# Epoch number: 431 and the loss: 7.139835834503174
# Epoch number: 441 and the loss: 7.035622596740723
# Epoch number: 451 and the loss: 6.925055980682373
# Epoch number: 461 and the loss: 6.993106842041016
# Epoch number: 471 and the loss: 6.8500447273254395
# Epoch number: 481 and the loss: 6.725698471069336
# Epoch number: 491 and the loss: 6.635984897613525

# %%
# Plotting the loss function
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(range(epochs), final_losses)
plt.ylabel('Loss')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
# Prediction in X_test data
predictions = []
with torch.no_grad():
    for i, data in enumerate(X_test.float()):
        #print(model(data))
        y_pred = model(data)
        predictions.append(y_pred)
        print(y_pred.item())
# Out:
# 10.636001586914062
# 10.903411865234375
# 10.033238410949707
# 12.758578300476074
# 11.500589370727539
# 12.253450393676758
# 10.642833709716797
# 12.37554931640625
# 10.645084381103516
# 10.975042343139648
# 9.159271240234375
# 11.106087684631348
# 9.820834159851074
# 10.838858604431152
# 10.898880958557129
# 11.680319786071777
# 11.076003074645996
# 11.161337852478027
# 10.647737503051758
# 10.841696739196777

# %%
diabetes_data = pd.read_csv('diabetes.csv')

# %%
diabetes_data.head()
# age	bmi	gender	glucose
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Assigning gender as male if pregnancies = 0, for the purpose of model analysis only.
diabetes_data['gender'] = [1 if x > 0 else 0 for x in diabetes_data['Pregnancies']]

# %%
diabetes_data = diabetes_data[['Age','BMI', 'gender', 'Glucose']]

# %%
diabetes_data.head()
# Out:
#    Age   BMI  gender  Glucose
# 0   50  33.6       1      148
# 1   31  26.6       1       85
# 2   32  23.3       1      183
# 3   21  28.1       1       89
# 4   33  43.1       0      137

# %%
X_diabetes=diabetes_data.values### independent features
X_diabetes = torch.tensor(X_diabetes)

# %%
diabetes_predictions = []
with torch.no_grad():
    for i, data in enumerate(X_diabetes.float()):
        #print(model(data))
        y_pred = model(data)
        diabetes_predictions.append(y_pred.item())
        print(y_pred.item())
# Out:
# 10.402824401855469
# 8.664446830749512
# 9.084457397460938
# 9.726688385009766
# 10.722418785095215
# 9.368507385253906
# 9.22707462310791
# 10.566469192504883
# 9.517035484313965
# 9.846619606018066
# 10.202312469482422
# 8.710983276367188
# 8.785484313964844
# 9.766576766967773
# 9.873510360717773
# 9.27325439453125
# 9.487802505493164
# 10.262686729431152
# 8.5504150390625
# 10.83073616027832
# 11.306811332702637
# 9.568004608154297
# 10.865534782409668
# 10.533544540405273
# 11.121193885803223
# 10.863495826721191
# 10.371705055236816
# 9.664729118347168
# 11.632739067077637
# 9.8709077835083
# 10.357843399047852
# 10.647408485412598
# 11.104775428771973
# 8.75324821472168
# 10.32446575164795
# 10.691154479980469
# 11.28419303894043
# 10.030777931213379
# 10.546113014221191
# 9.371603965759277
# 9.855937004089355
# 8.773943901062012
# 8.448811531066895
# 10.739944458007812
# 9.611669540405273
# 9.70616340637207
# 8.970088005065918
# 9.700479507446289
# 8.824020385742188
# 9.39900016784668
# 8.971220016479492
# 11.745213508605957
# 9.368770599365234
# 11.457468032836914
# 9.931367874145508
# 10.953022003173828
# 8.751152992248535
# 10.440850257873535
# 9.993841171264648
# 8.511308670043945
# 9.927383422851562
# 10.409256935119629
# 9.902841567993164
# 10.326688766479492
# 11.369779586791992
# 10.856908798217773
# 9.328664779663086
# 10.025495529174805
# 7.163325786590576
# 9.63172435760498
# 10.847896575927734
# 9.648096084594727
# 9.678966522216797
# 10.139671325683594
# 10.910138130187988
# 8.781111717224121
# 9.600122451782227
# 10.541296005249023
# 10.303610801696777
# 9.918807983398438
# 9.691279411315918
# 10.786067008972168
# 9.532756805419922
# 9.65622329711914
# 10.35546875
# 10.874944686889648
# 10.459053993225098
# 10.673861503601074
# 9.8324613571167
# 9.310946464538574
# 8.692305564880371
# 9.101838111877441
# 9.788216590881348
# 9.149947166442871
# 10.704300880432129
# 9.107613563537598
# 9.936397552490234
# 9.79615592956543
# 8.80496597290039
# 9.84808349609375
# 9.46299934387207
# 10.791726112365723
# 11.39297103881836
# 9.406820297241211
# 9.08952808380127
# 10.6928129196167
# 11.062102317810059
# 10.168679237365723
# 10.954998970031738
# 10.697027206420898
# 10.820196151733398
# 10.454411506652832
# 9.453179359436035
# 10.219449996948242
# 9.044763565063477
# 10.546401023864746
# 10.757080078125
# 10.512290954589844
# 10.33481216430664
# 10.824687004089355
# 9.921306610107422
# 12.16278076171875
# 8.952917098999023
# 11.607587814331055
# 9.024283409118652
# 10.995882987976074
# 10.01669979095459
# 9.379721641540527
# 10.462298393249512
# 9.177986145019531

# %%
diabetes_data['h1_hemoglobin'] = diabetes_predictions

# %%
display(diabetes_data)
# Out:
#      Age   BMI  gender  Glucose  h1_hemoglobin
# 0     50  33.6       1      148      11.048162
# 1     31  26.6       1       85       9.235365
# 2     32  23.3       1      183       9.395720
# 3     21  28.1       1       89       8.889082
# 4     33  43.1       0      137      10.597265
# ..   ...   ...     ...      ...            ...
# 763   63  32.9       1      101      10.995883
# 764   27  36.8       1      122      10.016700
# 765   30  26.2       1      121       9.379722
# 766   47  30.1       1      126      10.462298
# 767   23  30.4       1       93       9.177986
#
# [768 rows x 5 columns]
